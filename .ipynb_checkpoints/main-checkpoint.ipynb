# %% [markdown]
# ## CONFIG STEPS ##

# %%
# !pip install dvc[gcs]

# %%
# !git branch

# %%
import os

if not os.path.exists(".dvc"):
    # !dvc init
else:
    print("DVC already initialized.")
# Out:
# Initialized DVC repository.
#
# You can now commit the changes to git.
#
# +---------------------------------------------------------------------+
# |                                                                     |
# |        DVC has enabled anonymous aggregate usage analytics.         |
# |     Read the analytics documentation (and how to opt-out) here:     |
# |             <https://dvc.org/doc/user-guide/analytics>              |
# |                                                                     |
# +---------------------------------------------------------------------+
#
# What's next?
# ------------
# - Check out the documentation: <https://dvc.org/doc>
# - Get help and share ideas: <https://dvc.org/chat>
# - Star us on GitHub: <https://github.com/treeverse/dvc>

# %%
# !dvc remote add -d gcsremote gs://irisdata-week2-dvc

# %%
# !cat .dvc/config
# Out:
# [core]
#     remote = gcsremote
# ['remote "gcsremote"']
#     url = gs://irisdata-week2-dvc

# %%
import os

os.makedirs(
    "data",
    exist_ok=True
)

os.makedirs(
    "models",
    exist_ok=True
)

os.makedirs(
    "metrics",
    exist_ok=True
)

# %%
# !dvc push
# Out:
# ...
# Pushing
# Everything is up to date.

# %% [markdown]
# ## RUN FROM HERE ##

# %%
# !python train.py
# Out:
# Training Complete
# Accuracy: 0.9

# %%
# !python inference.py
# Out:
# Inference Complete
# Accuracy: 0.9

# %%
# !dvc add models/model.pkl
# !dvc add metrics/train_metrics.json
# !dvc add metrics/inference_metrics.json
# !dvc add metrics/classification_report.txt
# !git add .
# !git commit -m "Dataset + Model version 1"
# Out:
# ⠋ Checking graph
# Adding...
# !
# ...
#
# !
#   0% Checking cache in '/home/jupyter/21F3001992_MLOPS_WEEKLY_ASSIGNMENT/.dvc/ca
#
# !
#   0%|          |Checking out /home/jupyter/21F3001992_0/1 [00:00<?,    ?files/s]
# 100% Adding...|████████████████████████████████████████|1/1 [00:00, 19.45file/s]
#
# To track the changes with git, run:
#
# 	git add models/model.pkl.dvc
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# Adding...
# !
# ...
#
# !
#   0% Checking cache in '/home/jupyter/21F3001992_MLOPS_WEEKLY_ASSIGNMENT/.dvc/ca
#
# !
#   0%|          |Checking out /home/jupyter/21F3001992_0/1 [00:00<?,    ?files/s]
# 100% Adding...|████████████████████████████████████████|1/1 [00:00, 51.94file/s]
#
# To track the changes with git, run:
#
# 	git add metrics/train_metrics.json.dvc
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# Adding...
# !
# ...
#
# !
# ...

# %%
## TO BE RUN ON TERMINAL> git push origin week_2
# !dvc push
# Out:
# ...
# Pushing
# !
#   0% Checking cache in 'irisdata-week2-dvc/files/md5'| |0/? [00:00<?,    ?files/
#
# !
#   0% Checking cache in '/home/jupyter/21F3001992_MLOPS_WEEKLY_ASSIGNMENT/.dvc/ca
#
# !
#   0%|          |Pushing to gs                         0/4 [00:00<?,     ?file/s]
#
# !
#
#   0%|          |/home/jupyter/21F3001992_MLOPS_W0.00/23.0 [00:00<?,        ?B/s]
#
# 100%|██████████|/home/jupyter/21F3001992_MLO23.0/23.0 [00:00<00:00,      226B/s]
#
#
#  25%|██▌       |Pushing to gs                     1/4 [00:00<00:00,  6.09file/s]
#
# !
#
#   0%|          |/home/jupyter/21F3001992_MLOPS_WE0.00/380 [00:00<?,        ?B/s]
#
#
# !
#
#
#   0%|          |/home/jupyter/21F3001992_MLOPS_W0.00/40.0 [00:00<?,        ?B/s]
#
#
#
# !
#
#
#
#   0%|          |/home/jupyter/21F3001992_MLOPS_W0.00/158k [00:00<?,        ?B/s]
#
#
#
#
#
#
#
#
# 100%|██████████|/home/jupyter/21F3001992_MLO40.0/40.0 [00:00<00:00,      268B/s]
#
#
#
# ...

# %%
import pandas as pd

df = pd.read_csv(
    "data/iris.csv"
)

extra = df.sample(
    20,
    random_state=42
)

df = pd.concat(
    [df, extra],
    ignore_index=True
)

df.to_csv(
    "data/iris.csv",
    index=False
)

print(df.shape)
# Out:
# (170, 5)

# %%
# !python train.py
# Out:
# Training Complete
# Accuracy: 0.9411764705882353

# %%
# !python inference.py
# Out:
# Inference Complete
# Accuracy: 0.9411764705882353

# %%
# !dvc add models/model.pkl
# !dvc add metrics/train_metrics.json
# !dvc add metrics/inference_metrics.json
# !dvc add metrics/classification_report.txt
# !git add .
# !git commit -m "Dataset + Model version 2"
# Out:
# ⠋ Checking graph
# Adding...
# !
# ...
#
# !
#   0% Checking cache in '/home/jupyter/21F3001992_MLOPS_WEEKLY_ASSIGNMENT/.dvc/ca
#
# !
#   0%|          |Checking out /home/jupyter/21F3001992_0/1 [00:00<?,    ?files/s]
# 100% Adding...|████████████████████████████████████████|1/1 [00:00, 31.80file/s]
#
# To track the changes with git, run:
#
# 	git add models/model.pkl.dvc
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# Adding...
# !
# ...
#
# !
#   0% Checking cache in '/home/jupyter/21F3001992_MLOPS_WEEKLY_ASSIGNMENT/.dvc/ca
#
# !
#   0%|          |Checking out /home/jupyter/21F3001992_0/1 [00:00<?,    ?files/s]
# 100% Adding...|████████████████████████████████████████|1/1 [00:00, 43.98file/s]
#
# To track the changes with git, run:
#
# 	git add metrics/train_metrics.json.dvc
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# Adding...
# !
# ...
#
# !
# ...

# %%
## RUN ON TERMINAL > git push origin week_2
# !dvc push
# Out:
# ...
# Pushing
# !
#   0% Checking cache in 'irisdata-week2-dvc/files/md5'| |0/? [00:00<?,    ?files/
#
# !
#   0% Checking cache in '/home/jupyter/21F3001992_MLOPS_WEEKLY_ASSIGNMENT/.dvc/ca
#
# !
#   0%|          |Pushing to gs                         0/4 [00:00<?,     ?file/s]
#
# !
#
#   0%|          |/home/jupyter/21F3001992_MLOPS_W0.00/55.0 [00:00<?,        ?B/s]
#
#
#  25%|██▌       |Pushing to gs                     1/4 [00:00<00:00,  5.82file/s]
#
# !
#
#   0%|          |/home/jupyter/21F3001992_MLOPS_W0.00/156k [00:00<?,        ?B/s]
#
#
# !
#
#
#   0%|          |/home/jupyter/21F3001992_MLOPS_W0.00/38.0 [00:00<?,        ?B/s]
#
#
#
# !
#
#
#
#   0%|          |/home/jupyter/21F3001992_MLOPS_WE0.00/380 [00:00<?,        ?B/s]
#
#
#
#
#
#
#
#
# 100%|██████████|/home/jupyter/21F3001992_MLO156k/156k [00:00<00:00,    1.26MB/s]
#
#
# 100%|██████████|Pushing to gs                     4/4 [00:00<00:00, 14.86file/s]
# Pushing
# 4 files pushed

# %%
# Show history
# !git log --oneline
# Out:
# f9df6eb (HEAD -> week_2, origin/week_2) Dataset + Model version 2
# 045dbba Dataset + Model version 1
# b22356e Added Readme
# 874c43b Clean Week2

# %%
# Restore Version 1
# !git checkout 045dbba
# !dvc checkout
# Out:
# M	main.ipynb
# Note: switching to '045dbba'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 045dbba Dataset + Model version 1
# Building workspace index                              |6.00 [00:00, 10.7entry/s]
# Comparing indexes                                    |7.00 [00:00, 1.92kentry/s]
# Applying changes                                      |4.00 [00:00,   703file/s]
# M       metrics/classification_report.txt
# M       metrics/inference_metrics.json
# ...

# %%
# Run inference
# !python inference.py
# Out:
# Inference Complete
# Accuracy: 0.9

# %%
# !dvc push
# Out:
# ...
# Pushing
# !
#   0% Checking cache in 'irisdata-week2-dvc/files/md5'| |0/? [00:00<?,    ?files/
#  25% Querying cache in 'irisdata-week2-dvc/files/md5'|▎|1/4 [00:00<00:00,  3.68f
# Pushing
# Everything is up to date.
# I0626 14:43:18.925432   50521 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# I0626 14:43:18.932770   50521 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers

# %%
# !git checkout week_2
# !dvc pull
# Out:
# M	main.ipynb
# Previous HEAD position was 045dbba Dataset + Model version 1
# Switched to branch 'week_2'
# ...
# Fetching
# !
#   0% Checking cache in '/home/jupyter/21F3001992_MLOPS_WEEKLY_ASSIGNMENT/.dvc/ca
# Fetching
# Building workspace index                              |6.00 [00:00,  496entry/s]
# Comparing indexes                                    |7.00 [00:00, 1.84kentry/s]
# Applying changes                                      |4.00 [00:00, 1.61kfile/s]
# M       metrics/classification_report.txt
# M       metrics/inference_metrics.json
# M       metrics/train_metrics.json
# M       models/model.pkl
# 4 files modified
# I0626 14:44:51.646914   50801 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# I0626 14:44:51.654029   50801 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers

# %%
# !git log --oneline --decorate --graph --all
# Out:
# * f9df6eb (HEAD -> week_2, origin/week_2) Dataset + Model version 2
# * 045dbba Dataset + Model version 1
# * b22356e Added Readme
# * 874c43b Clean Week2
# * b715ed7 (origin/week_1, origin/HEAD, week_1) Week 1 Vertex AI Iris Pipeline

# %%
# !git checkout f9df6eb
# Out:
# M	main.ipynb
# Note: switching to 'f9df6eb'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at f9df6eb Dataset + Model version 2

# %%
# !python inference.py
# Out:
# Inference Complete
# Accuracy: 0.9411764705882353
